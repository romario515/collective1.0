# %%
import os
from ultralytics import YOLO

def normalize_annotation(annotation_path):
    with open(annotation_path, 'r') as file:
        lines = file.readlines()

    normalized_lines = []
    for line in lines:
        parts = line.strip().split()
        class_id = parts[0]
        coordinates = list(map(float, parts[1:]))

        # Проверка и нормализация координат
        for i in range(len(coordinates)):
            if coordinates[i] < 0:
                coordinates[i] = 0
            elif coordinates[i] > 1:
                coordinates[i] = 1

        normalized_line = f"{class_id} " + " ".join(map(str, coordinates))
        normalized_lines.append(normalized_line)

    with open(annotation_path, 'w') as file:
        file.write("\n".join(normalized_lines))

def normalize_annotations_in_directory(directory):
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.txt'):
                annotation_path = os.path.join(root, file)
                normalize_annotation(annotation_path)

# Нормализация аннотаций
normalize_annotations_in_directory('/home/jupyter/work/resources/dataset_rr/train/labels')
normalize_annotations_in_directory('/home/jupyter/work/resources/dataset_rr/valid/labels')
normalize_annotations_in_directory('/home/jupyter/work/resources/dataset_rr/test/labels')

# Загрузка модели с архитектурой YOLOv8
model = YOLO('yolov8.yaml')

# Обучение модели
model.train(data='data.yaml', epochs=100, imgsz=640,batch=32, workers=8)

# %%
import os
from ultralytics import YOLO

# Путь к сохраненной модели после первых 20 эпох
model_path = 'runs/detect/train2/weights/best.pt'  # Убедитесь, что путь правильный

# Загрузка модели с сохраненного состояния
model = YOLO(model_path)

# Обучение модели
model.train(data='data.yaml', epochs=40, imgsz=640, batch=32, workers=8)

# %%
import os
from ultralytics import YOLO

def normalize_annotation(annotation_path):
    with open(annotation_path, 'r') as file:
        lines = file.readlines()

    normalized_lines = []
    for line in lines:
        parts = line.strip().split()
        class_id = parts[0]
        coordinates = list(map(float, parts[1:]))

        # Проверка и нормализация координат
        for i in range(len(coordinates)):
            if coordinates[i] < 0:
                coordinates[i] = 0
            elif coordinates[i] > 1:
                coordinates[i] = 1

        normalized_line = f"{class_id} " + " ".join(map(str, coordinates))
        normalized_lines.append(normalized_line)

    with open(annotation_path, 'w') as file:
        file.write("\n".join(normalized_lines))

def normalize_annotations_in_directory(directory):
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.txt'):
                annotation_path = os.path.join(root, file)
                normalize_annotation(annotation_path)

# Нормализация аннотаций
normalize_annotations_in_directory('/home/jupyter/work/resources/dataset_rr/train/labels')
normalize_annotations_in_directory('/home/jupyter/work/resources/dataset_rr/valid/labels')
normalize_annotations_in_directory('/home/jupyter/work/resources/dataset_rr/test/labels')

# Путь к предобученной модели YOLOv8
pretrained_model_path = 'yolov8n.pt'  # Замените на путь к вашей предобученной модели

# Загрузка предобученной модели
model = YOLO(pretrained_model_path)

# Обучение модели
model.train(
    data='data.yaml', 
    epochs=100,         # Общее количество эпох
    imgsz=640,         # Размер изображений
    batch=64,          # Размер батча, увеличьте до максимума, который ваша GPU может обрабатывать без ошибки памяти
    workers=8,         # Количество рабочих потоков для загрузки данных
)

# %%
# %pip install datasets==2.3.2 fsspec==2021.7.0 s3fs==2021.7.0

# %%
import os
import pandas as pd
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
import torch
import json
from sklearn.model_selection import train_test_split

# Функция для чтения данных из текстовых файлов
def read_data(data_dir):
    data = []
    label_to_id = {}
    label_id = 0
    for label in os.listdir(data_dir):
        label_dir = os.path.join(data_dir, label)
        if os.path.isdir(label_dir):
            if label not in label_to_id:
                label_to_id[label] = label_id
                label_id += 1
            for file in os.listdir(label_dir):
                if file.endswith('.txt'):
                    file_path = os.path.join(label_dir, file)
                    with open(file_path, 'r') as f:
                        lines = f.readlines()
                        count_str = lines[0].strip()
                        combined_lines = ''.join(lines[1:]).strip()
                        data.append((combined_lines, label_to_id[label]))
    return pd.DataFrame(data, columns=['text', 'label']), label_to_id

# Чтение данных
train_data, train_label_to_id = read_data('/home/jupyter/work/resources/dataset/train/')
valid_data, valid_label_to_id = read_data('/home/jupyter/work/resources/dataset/validate')

# Сохранение словаря меток
os.makedirs('/home/jupyter/work/resources/results', exist_ok=True)
with open('/home/jupyter/work/resources/results/label_to_id.json', 'w') as f:
    json.dump(train_label_to_id, f)

# Разделение данных на тренировочные и валидационные
train_texts, valid_texts, train_labels, valid_labels = train_test_split(
    train_data['text'], train_data['label'], test_size=0.1
)

# Токенизация данных
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
train_encodings = tokenizer(list(train_texts), truncation=True, padding=True, return_tensors="pt")
valid_encodings = tokenizer(list(valid_texts), truncation=True, padding=True, return_tensors="pt")

# Создание PyTorch датасетов
class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: val[idx] for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

train_dataset = CustomDataset(train_encodings, list(train_labels))
valid_dataset = CustomDataset(valid_encodings, list(valid_labels))

# Загрузка модели BERT
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=len(train_label_to_id))

# Настройка параметров обучения
# Настройка параметров обучения
training_args = TrainingArguments(
    output_dir='/home/jupyter/work/resources/results',
    evaluation_strategy="epoch",  # Обновите evaluation_strategy на eval_strategy
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=3,
    weight_decay=0.01,
    save_strategy="epoch",  # Сохранение модели на каждой эпохе
)

# Создание тренера
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=valid_dataset,
)

# Обучение модели
trainer.train()

# Сохранение модели
model.save_pretrained('/home/jupyter/work/resources/results')
tokenizer.save_pretrained('/home/jupyter/work/resources/results')

# %%
import torch
from transformers import BertTokenizer, BertForSequenceClassification
import json

# Абсолютные пути
RESULTS_DIR = '/home/jupyter/work/resources/results'

# Загрузка токенизатора и модели
tokenizer = BertTokenizer.from_pretrained(f'{RESULTS_DIR}')
model = BertForSequenceClassification.from_pretrained(f'{RESULTS_DIR}')

# Загрузка словаря меток
with open(f'{RESULTS_DIR}/label_to_id.json', 'r') as f:
    label_to_id = json.load(f)

# Обратный словарь для отображения меток
id_to_label = {v: k for k, v in label_to_id.items()}

# Функция для предсказания на входном тексте
def predict(text):
    inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True, max_length=512)
    outputs = model(**inputs)
    predictions = torch.nn.functional.softmax(outputs.logits, dim=-1)
    return predictions


# Входные данные
input_text = """
2
Model 3|rail|83.95|730.3089599609375|0.0|255.2872314453125|680.51123046875
Model 3|rail|27.05|517.669921875|11.56787109375|144.6182861328125|676.1633911132812

"""

# Обработка текста для модели
lines = input_text.strip().split('\n')
count = lines[0]
text_lines = '\n'.join(lines[1:])

# Предсказание
predictions = predict(text_lines)
predicted_label_id = torch.argmax(predictions, dim=1).item()

# Вывод предсказаний
predicted_label = id_to_label[predicted_label_id]
print(f"Predicted label: {predicted_label}")

# Вывод вероятностей для всех классов
for i, prob in enumerate(predictions[0]):
    label = id_to_label[i]
    print(f"{label}: {prob.item() * 100:.2f}%")

# %%
# %pip install odfpy

# %%
# Укажите путь к вашему скрипту
script_path = "/home/jupyter/work/resources/console_yandex/console.py"

# Задайте значение переменной __file__
globals()['__file__'] = script_path

# Выполните скрипт
exec(open(script_path).read())
# Out:
# /home/jupyter/work/resources/console_yandex
#
# 0: 384x640 1 machinery, 9.7ms
# Speed: 2.7ms preprocess, 9.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0.0 ---------------------------
#
# 0: 384x640 2 trains, 10.3ms
# Speed: 1.8ms preprocess, 10.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0.0 ---------------------------
# 0.0 ---------------------------
#
# 0: 384x640 3 rails, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0.0 ---------------------------
# 0.0 ---------------------------
# 0.0 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 (no detections), 11.1ms
# Speed: 2.6ms preprocess, 11.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 trains, 8.8ms
# Speed: 1.9ms preprocess, 8.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 0.23356666666666667 ---------------------------
# 0.23356666666666667 ---------------------------
# 0.23356666666666667 ---------------------------
#
# 0: 384x640 1 rail, 9.3ms
# Speed: 1.7ms preprocess, 9.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0.23356666666666667 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 (no detections), 12.1ms
# Speed: 2.4ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 9.1ms
# Speed: 1.7ms preprocess, 9.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0.46713333333333334 ---------------------------
#
# 0: 384x640 1 rail, 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0.46713333333333334 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 machinery, 11.6ms
# Speed: 3.0ms preprocess, 11.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0.7007 ---------------------------
#
# 0: 384x640 2 trains, 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 0.7007 ---------------------------
# 0.7007 ---------------------------
#
# 0: 384x640 2 rails, 9.3ms
# Speed: 1.7ms preprocess, 9.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 0.7007 ---------------------------
# 0.7007 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 3 machinerys, 9.7ms
# Speed: 2.9ms preprocess, 9.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0.9342666666666667 ---------------------------
# 0.9342666666666667 ---------------------------
# 0.9342666666666667 ---------------------------
#
# 0: 384x640 3 trains, 9.0ms
# Speed: 1.8ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0.9342666666666667 ---------------------------
# 0.9342666666666667 ---------------------------
# 0.9342666666666667 ---------------------------
#
# 0: 384x640 2 rails, 9.0ms
# Speed: 1.7ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 0.9342666666666667 ---------------------------
# 0.9342666666666667 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 (no detections), 11.1ms
# Speed: 2.2ms preprocess, 11.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 1.1678333333333333 ---------------------------
#
# 0: 384x640 1 rail, 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 1.1678333333333333 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 (no detections), 10.3ms
# Speed: 2.4ms preprocess, 10.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.3ms
# Speed: 1.5ms preprocess, 9.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 rail, 8.9ms
# Speed: 1.6ms preprocess, 8.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 1.4014 ---------------------------
# Predicted label: not
#
# 0: 384x640 (no detections), 11.0ms
# Speed: 2.4ms preprocess, 11.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 rail, 9.0ms
# Speed: 1.7ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 1.6349666666666667 ---------------------------
# Predicted label: not
#
# 0: 384x640 2 machinerys, 12.0ms
# Speed: 2.2ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 1.8685333333333334 ---------------------------
# 1.8685333333333334 ---------------------------
#
# 0: 384x640 2 trains, 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1.8685333333333334 ---------------------------
# 1.8685333333333334 ---------------------------
#
# 0: 384x640 3 rails, 8.7ms
# Speed: 1.7ms preprocess, 8.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1.8685333333333334 ---------------------------
# 1.8685333333333334 ---------------------------
# 1.8685333333333334 ---------------------------
# Predicted label: not
#
# 0: 384x640 (no detections), 12.1ms
# Speed: 2.5ms preprocess, 12.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 2.1021 ---------------------------
#
# 0: 384x640 (no detections), 9.1ms
# Speed: 1.7ms preprocess, 9.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Predicted label: not
#
# 0: 384x640 (no detections), 11.7ms
# Speed: 2.3ms preprocess, 11.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 9.0ms
# Speed: 1.8ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 2.3356666666666666 ---------------------------
#
# 0: 384x640 1 rail, 9.3ms
# Speed: 1.9ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 2.3356666666666666 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 Mask, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 2.5692333333333335 ---------------------------
#
# 0: 384x640 1 train, 9.0ms
# Speed: 1.7ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 2.5692333333333335 ---------------------------
#
# 0: 384x640 (no detections), 9.0ms
# Speed: 1.8ms preprocess, 9.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# До not После zalez1
# Predicted label: zalez1
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 2.1ms preprocess, 10.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 9.3ms
# Speed: 1.7ms preprocess, 9.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 2.8028 ---------------------------
# 2.8028 ---------------------------
#
# 0: 384x640 1 rail, 9.0ms
# Speed: 1.8ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 2.8028 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 (no detections), 11.5ms
# Speed: 3.3ms preprocess, 11.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 trains, 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 3.036366666666667 ---------------------------
# 3.036366666666667 ---------------------------
# 3.036366666666667 ---------------------------
#
# 0: 384x640 1 rail, 9.0ms
# Speed: 1.7ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 3.036366666666667 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 (no detections), 12.9ms
# Speed: 2.4ms preprocess, 12.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 9.3ms
# Speed: 1.9ms preprocess, 9.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 3.2699333333333334 ---------------------------
#
# 0: 384x640 (no detections), 8.7ms
# Speed: 1.7ms preprocess, 8.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Predicted label: not
#
# 0: 384x640 (no detections), 14.1ms
# Speed: 2.3ms preprocess, 14.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 3.5035000000000003 ---------------------------
#
# 0: 384x640 (no detections), 9.0ms
# Speed: 1.7ms preprocess, 9.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Predicted label: not
#
# 0: 384x640 (no detections), 13.6ms
# Speed: 2.4ms preprocess, 13.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 9.3ms
# Speed: 1.8ms preprocess, 9.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 3.7370666666666668 ---------------------------
# 3.7370666666666668 ---------------------------
#
# 0: 384x640 1 rail, 9.6ms
# Speed: 1.6ms preprocess, 9.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 3.7370666666666668 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 (no detections), 9.8ms
# Speed: 2.4ms preprocess, 9.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 9.0ms
# Speed: 1.7ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 3.9706333333333332 ---------------------------
# 3.9706333333333332 ---------------------------
#
# 0: 384x640 4 rails, 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 3.9706333333333332 ---------------------------
# 3.9706333333333332 ---------------------------
# 3.9706333333333332 ---------------------------
# 3.9706333333333332 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 machinery, 12.6ms
# Speed: 2.5ms preprocess, 12.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 4.2042 ---------------------------
#
# 0: 384x640 2 trains, 9.1ms
# Speed: 1.8ms preprocess, 9.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 4.2042 ---------------------------
# 4.2042 ---------------------------
#
# 0: 384x640 2 rails, 1 sleepers, 8.7ms
# Speed: 1.6ms preprocess, 8.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 4.2042 ---------------------------
# 4.2042 ---------------------------
# 4.2042 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 (no detections), 10.4ms
# Speed: 2.1ms preprocess, 10.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 9.3ms
# Speed: 1.8ms preprocess, 9.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 4.437766666666667 ---------------------------
# 4.437766666666667 ---------------------------
#
# 0: 384x640 1 rail, 9.3ms
# Speed: 1.7ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 4.437766666666667 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 (no detections), 10.3ms
# Speed: 2.6ms preprocess, 10.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 9.1ms
# Speed: 1.7ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 4.671333333333333 ---------------------------
# 4.671333333333333 ---------------------------
#
# 0: 384x640 1 rail, 9.1ms
# Speed: 1.8ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 4.671333333333333 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 3 machinerys, 12.5ms
# Speed: 2.3ms preprocess, 12.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 4.9049000000000005 ---------------------------
# 4.9049000000000005 ---------------------------
# 4.9049000000000005 ---------------------------
#
# 0: 384x640 1 person, 2 trains, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 4.9049000000000005 ---------------------------
# 4.9049000000000005 ---------------------------
# 4.9049000000000005 ---------------------------
#
# 0: 384x640 3 rails, 8.7ms
# Speed: 2.2ms preprocess, 8.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 4.9049000000000005 ---------------------------
# 4.9049000000000005 ---------------------------
# 4.9049000000000005 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 (no detections), 9.6ms
# Speed: 2.3ms preprocess, 9.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 5.138466666666667 ---------------------------
# 5.138466666666667 ---------------------------
#
# 0: 384x640 2 rails, 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 5.138466666666667 ---------------------------
# 5.138466666666667 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 (no detections), 12.4ms
# Speed: 2.6ms preprocess, 12.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 trains, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 5.372033333333333 ---------------------------
# 5.372033333333333 ---------------------------
# 5.372033333333333 ---------------------------
#
# 0: 384x640 2 rails, 1 railway, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 5.372033333333333 ---------------------------
# 5.372033333333333 ---------------------------
# 5.372033333333333 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 (no detections), 9.7ms
# Speed: 2.1ms preprocess, 9.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 5.6056 ---------------------------
#
# 0: 384x640 5 rails, 1 railway, 1 sleepers, 9.1ms
# Speed: 1.7ms preprocess, 9.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 5.6056 ---------------------------
# 5.6056 ---------------------------
# 5.6056 ---------------------------
# 5.6056 ---------------------------
# 5.6056 ---------------------------
# 5.6056 ---------------------------
# 5.6056 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 (no detections), 11.7ms
# Speed: 2.4ms preprocess, 11.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 8.8ms
# Speed: 1.9ms preprocess, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 5.839166666666666 ---------------------------
# 5.839166666666666 ---------------------------
#
# 0: 384x640 2 rails, 1 railway, 1 sleepers, 9.1ms
# Speed: 1.7ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 5.839166666666666 ---------------------------
# 5.839166666666666 ---------------------------
# 5.839166666666666 ---------------------------
# 5.839166666666666 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 Hardhat, 1 machinery, 11.4ms
# Speed: 2.8ms preprocess, 11.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 6.072733333333334 ---------------------------
# 6.072733333333334 ---------------------------
#
# 0: 384x640 1 train, 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 6.072733333333334 ---------------------------
#
# 0: 384x640 1 rail, 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 6.072733333333334 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 (no detections), 11.1ms
# Speed: 2.5ms preprocess, 11.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 6.3063 ---------------------------
# 6.3063 ---------------------------
#
# 0: 384x640 1 rail, 9.4ms
# Speed: 1.9ms preprocess, 9.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 6.3063 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 machinery, 9.6ms
# Speed: 2.1ms preprocess, 9.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 6.539866666666667 ---------------------------
#
# 0: 384x640 2 trains, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 6.539866666666667 ---------------------------
# 6.539866666666667 ---------------------------
#
# 0: 384x640 3 rails, 9.1ms
# Speed: 1.8ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 6.539866666666667 ---------------------------
# 6.539866666666667 ---------------------------
# 6.539866666666667 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 machinery, 12.3ms
# Speed: 2.4ms preprocess, 12.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 6.773433333333333 ---------------------------
#
# 0: 384x640 (no detections), 9.2ms
# Speed: 2.3ms preprocess, 9.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 rail, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 6.773433333333333 ---------------------------
# До not После slez1
# Predicted label: slez1
#
# 0: 384x640 1 Safety Cone, 10.4ms
# Speed: 2.5ms preprocess, 10.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 7.007000000000001 ---------------------------
#
# 0: 384x640 1 train, 9.1ms
# Speed: 1.7ms preprocess, 9.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 7.007000000000001 ---------------------------
#
# 0: 384x640 1 rail, 1 railway, 9.1ms
# Speed: 1.5ms preprocess, 9.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 7.007000000000001 ---------------------------
# 7.007000000000001 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 Safety Cone, 1 machinery, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 7.240566666666667 ---------------------------
# 7.240566666666667 ---------------------------
#
# 0: 384x640 1 person, 1 train, 9.1ms
# Speed: 1.9ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 7.240566666666667 ---------------------------
# 7.240566666666667 ---------------------------
#
# 0: 384x640 (no detections), 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# До slez1 После Kaska2
# Predicted label: Kaska2
#
# 0: 384x640 1 NO-Safety Vest, 1 Person, 11.0ms
# Speed: 2.5ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 7.4741333333333335 ---------------------------
# 7.4741333333333335 ---------------------------
#
# 0: 384x640 2 trains, 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 7.4741333333333335 ---------------------------
# 7.4741333333333335 ---------------------------
#
# 0: 384x640 1 rail, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 7.4741333333333335 ---------------------------
# До Kaska2 После zalez1
# Predicted label: zalez1
# Match Vest!
#
# 0: 384x640 1 NO-Safety Vest, 1 Person, 1 vehicle, 9.4ms
# Speed: 3.2ms preprocess, 9.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 7.7077 ---------------------------
# 7.7077 ---------------------------
# 7.7077 ---------------------------
#
# 0: 384x640 1 train, 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 7.7077 ---------------------------
#
# 0: 384x640 3 rails, 9.2ms
# Speed: 1.6ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 7.7077 ---------------------------
# 7.7077 ---------------------------
# 7.7077 ---------------------------
# До zalez1 После zalez1
# Predicted label: zalez1
# Match Vest!
#
# 0: 384x640 3 NO-Safety Vests, 1 Person, 12.2ms
# Speed: 2.5ms preprocess, 12.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# 7.9412666666666665 ---------------------------
# 7.9412666666666665 ---------------------------
# 7.9412666666666665 ---------------------------
# 7.9412666666666665 ---------------------------
#
# 0: 384x640 1 train, 9.1ms
# Speed: 2.1ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 7.9412666666666665 ---------------------------
#
# 0: 384x640 6 rails, 9.4ms
# Speed: 2.1ms preprocess, 9.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 7.9412666666666665 ---------------------------
# 7.9412666666666665 ---------------------------
# 7.9412666666666665 ---------------------------
# 7.9412666666666665 ---------------------------
# 7.9412666666666665 ---------------------------
# 7.9412666666666665 ---------------------------
# До zalez1 После zalez1
# zalez1 7.9412666666666665 ==========
# Predicted label: zalez1
#
# 0: 384x640 (no detections), 11.9ms
# Speed: 2.4ms preprocess, 11.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 9.3ms
# Speed: 1.8ms preprocess, 9.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 8.174833333333334 ---------------------------
#
# 0: 384x640 2 rails, 9.3ms
# Speed: 1.7ms preprocess, 9.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 8.174833333333334 ---------------------------
# 8.174833333333334 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 machinery, 10.0ms
# Speed: 2.5ms preprocess, 10.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 8.4084 ---------------------------
#
# 0: 384x640 1 person, 2 trains, 9.1ms
# Speed: 1.8ms preprocess, 9.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 8.4084 ---------------------------
# 8.4084 ---------------------------
# 8.4084 ---------------------------
#
# 0: 384x640 1 rail, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 8.4084 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 Safety Cone, 1 machinery, 10.3ms
# Speed: 2.4ms preprocess, 10.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 8.641966666666667 ---------------------------
# 8.641966666666667 ---------------------------
#
# 0: 384x640 1 train, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# 8.641966666666667 ---------------------------
#
# 0: 384x640 2 rails, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 8.641966666666667 ---------------------------
# 8.641966666666667 ---------------------------
# Predicted label: not
#
# 0: 384x640 1 machinery, 12.1ms
# Speed: 2.4ms preprocess, 12.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 8.875533333333333 ---------------------------
#
# 0: 384x640 (no detections), 9.0ms
# Speed: 1.7ms preprocess, 9.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 rail, 8.6ms
# Speed: 1.7ms preprocess, 8.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 8.875533333333333 ---------------------------
# До not После slez1
# Predicted label: slez1
#
# 0: 384x640 1 machinery, 11.4ms
# Speed: 2.4ms preprocess, 11.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 9.1091 ---------------------------
#
# 0: 384x640 (no detections), 9.2ms
# Speed: 1.9ms preprocess, 9.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 rail, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 9.1091 ---------------------------
# До slez1 После slez1
# Predicted label: slez1
#
# 0: 384x640 1 NO-Safety Vest, 1 Person, 1 machinery, 12.2ms
# Speed: 2.5ms preprocess, 12.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 9.342666666666666 ---------------------------
# 9.342666666666666 ---------------------------
# 9.342666666666666 ---------------------------
#
# 0: 384x640 (no detections), 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 rail, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 9.342666666666666 ---------------------------
# До slez1 После zalez1
# Predicted label: zalez1
# Match Vest!
#
# 0: 384x640 2 machinerys, 11.5ms
# Speed: 2.5ms preprocess, 11.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 9.576233333333333 ---------------------------
# 9.576233333333333 ---------------------------
#
# 0: 384x640 (no detections), 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.3ms
# Speed: 1.9ms preprocess, 10.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# До zalez1 После zalez1
# Predicted label: zalez1
#
# 0: 384x640 1 NO-Safety Vest, 1 machinery, 10.0ms
# Speed: 2.5ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 9.809800000000001 ---------------------------
# 9.809800000000001 ---------------------------
#
# 0: 384x640 1 train, 9.2ms
# Speed: 1.9ms preprocess, 9.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 9.809800000000001 ---------------------------
#
# 0: 384x640 3 rails, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 9.809800000000001 ---------------------------
# 9.809800000000001 ---------------------------
# 9.809800000000001 ---------------------------
# До zalez1 После zalez1
# zalez1 9.809800000000001 ==========
# Predicted label: zalez1
#
# 0: 384x640 (no detections), 9.8ms
# Speed: 2.0ms preprocess, 9.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 8.7ms
# Speed: 1.7ms preprocess, 8.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 10.043366666666667 ---------------------------
# 10.043366666666667 ---------------------------
#
# 0: 384x640 1 rail, 8.8ms
# Speed: 1.7ms preprocess, 8.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 10.043366666666667 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 NO-Safety Vest, 10.3ms
# Speed: 2.6ms preprocess, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 10.276933333333334 ---------------------------
#
# 0: 384x640 1 train, 9.1ms
# Speed: 1.7ms preprocess, 9.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 10.276933333333334 ---------------------------
#
# 0: 384x640 (no detections), 9.4ms
# Speed: 1.7ms preprocess, 9.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Predicted label: blizko1
#
# 0: 384x640 1 machinery, 14.3ms
# Speed: 2.5ms preprocess, 14.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 10.5105 ---------------------------
#
# 0: 384x640 1 train, 9.5ms
# Speed: 1.9ms preprocess, 9.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 10.5105 ---------------------------
#
# 0: 384x640 1 rail, 9.6ms
# Speed: 1.8ms preprocess, 9.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 10.5105 ---------------------------
# Predicted label: not
#
# 0: 384x640 (no detections), 13.6ms
# Speed: 2.3ms preprocess, 13.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 rails, 8.8ms
# Speed: 1.7ms preprocess, 8.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 10.744066666666667 ---------------------------
# 10.744066666666667 ---------------------------
# До not После zalez1
# Predicted label: zalez1
#
# 0: 384x640 1 Person, 11.5ms
# Speed: 2.3ms preprocess, 11.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 10.977633333333333 ---------------------------
#
# 0: 384x640 (no detections), 9.0ms
# Speed: 1.9ms preprocess, 9.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 rails, 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 10.977633333333333 ---------------------------
# 10.977633333333333 ---------------------------
# До zalez1 После zalez1
# Predicted label: zalez1
#
# 0: 384x640 3 Persons, 11.1ms
# Speed: 2.5ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 11.2112 ---------------------------
# 11.2112 ---------------------------
# 11.2112 ---------------------------
#
# 0: 384x640 1 train, 10.3ms
# Speed: 1.8ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 11.2112 ---------------------------
#
# 0: 384x640 1 arrow, 2 rails, 9.3ms
# Speed: 1.7ms preprocess, 9.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 11.2112 ---------------------------
# 11.2112 ---------------------------
# 11.2112 ---------------------------
# До zalez1 После Kaska2
# Predicted label: Kaska2
#
# 0: 384x640 (no detections), 11.0ms
# Speed: 2.5ms preprocess, 11.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 trains, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 11.444766666666666 ---------------------------
# 11.444766666666666 ---------------------------
# 11.444766666666666 ---------------------------
# 11.444766666666666 ---------------------------
#
# 0: 384x640 2 rails, 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 11.444766666666666 ---------------------------
# 11.444766666666666 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 (no detections), 10.7ms
# Speed: 2.3ms preprocess, 10.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 trains, 9.0ms
# Speed: 1.7ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 11.678333333333333 ---------------------------
# 11.678333333333333 ---------------------------
# 11.678333333333333 ---------------------------
#
# 0: 384x640 3 rails, 8.8ms
# Speed: 1.6ms preprocess, 8.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 11.678333333333333 ---------------------------
# 11.678333333333333 ---------------------------
# 11.678333333333333 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 2 machinerys, 11.7ms
# Speed: 2.4ms preprocess, 11.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 11.911900000000001 ---------------------------
# 11.911900000000001 ---------------------------
#
# 0: 384x640 1 train, 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 11.911900000000001 ---------------------------
#
# 0: 384x640 2 rails, 9.7ms
# Speed: 2.2ms preprocess, 9.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 11.911900000000001 ---------------------------
# 11.911900000000001 ---------------------------
# Predicted label: not
#
# 0: 384x640 1 machinery, 9.7ms
# Speed: 2.2ms preprocess, 9.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 12.145466666666668 ---------------------------
#
# 0: 384x640 2 trains, 9.2ms
# Speed: 2.1ms preprocess, 9.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 12.145466666666668 ---------------------------
# 12.145466666666668 ---------------------------
#
# 0: 384x640 3 rails, 8.7ms
# Speed: 1.7ms preprocess, 8.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 12.145466666666668 ---------------------------
# 12.145466666666668 ---------------------------
# 12.145466666666668 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 2 machinerys, 14.5ms
# Speed: 2.4ms preprocess, 14.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 12.379033333333334 ---------------------------
# 12.379033333333334 ---------------------------
#
# 0: 384x640 2 trains, 9.4ms
# Speed: 1.7ms preprocess, 9.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 12.379033333333334 ---------------------------
# 12.379033333333334 ---------------------------
#
# 0: 384x640 2 rails, 9.0ms
# Speed: 1.8ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 12.379033333333334 ---------------------------
# 12.379033333333334 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 (no detections), 9.6ms
# Speed: 2.4ms preprocess, 9.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 12.6126 ---------------------------
# 12.6126 ---------------------------
#
# 0: 384x640 3 rails, 9.1ms
# Speed: 1.8ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 12.6126 ---------------------------
# 12.6126 ---------------------------
# 12.6126 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 Person, 12.1ms
# Speed: 2.4ms preprocess, 12.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 12.846166666666667 ---------------------------
#
# 0: 384x640 3 trains, 9.3ms
# Speed: 1.9ms preprocess, 9.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 12.846166666666667 ---------------------------
# 12.846166666666667 ---------------------------
# 12.846166666666667 ---------------------------
#
# 0: 384x640 3 rails, 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 12.846166666666667 ---------------------------
# 12.846166666666667 ---------------------------
# 12.846166666666667 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 Safety Cone, 1 machinery, 10.5ms
# Speed: 2.8ms preprocess, 10.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 13.079733333333333 ---------------------------
# 13.079733333333333 ---------------------------
#
# 0: 384x640 4 trains, 9.0ms
# Speed: 1.9ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 13.079733333333333 ---------------------------
# 13.079733333333333 ---------------------------
# 13.079733333333333 ---------------------------
# 13.079733333333333 ---------------------------
#
# 0: 384x640 4 rails, 9.5ms
# Speed: 1.6ms preprocess, 9.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 13.079733333333333 ---------------------------
# 13.079733333333333 ---------------------------
# 13.079733333333333 ---------------------------
# 13.079733333333333 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 Safety Cone, 1 machinery, 10.5ms
# Speed: 2.2ms preprocess, 10.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 13.3133 ---------------------------
# 13.3133 ---------------------------
#
# 0: 384x640 2 trains, 9.0ms
# Speed: 1.7ms preprocess, 9.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 13.3133 ---------------------------
# 13.3133 ---------------------------
#
# 0: 384x640 4 rails, 8.7ms
# Speed: 1.8ms preprocess, 8.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 13.3133 ---------------------------
# 13.3133 ---------------------------
# 13.3133 ---------------------------
# 13.3133 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 Safety Cone, 9.3ms
# Speed: 2.4ms preprocess, 9.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 13.546866666666666 ---------------------------
#
# 0: 384x640 4 trains, 9.0ms
# Speed: 1.8ms preprocess, 9.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 13.546866666666666 ---------------------------
# 13.546866666666666 ---------------------------
# 13.546866666666666 ---------------------------
# 13.546866666666666 ---------------------------
#
# 0: 384x640 3 rails, 8.8ms
# Speed: 1.7ms preprocess, 8.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 13.546866666666666 ---------------------------
# 13.546866666666666 ---------------------------
# 13.546866666666666 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 machinery, 13.9ms
# Speed: 2.6ms preprocess, 13.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 13.780433333333333 ---------------------------
#
# 0: 384x640 5 trains, 8.7ms
# Speed: 1.8ms preprocess, 8.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 13.780433333333333 ---------------------------
# 13.780433333333333 ---------------------------
# 13.780433333333333 ---------------------------
# 13.780433333333333 ---------------------------
# 13.780433333333333 ---------------------------
#
# 0: 384x640 4 rails, 9.0ms
# Speed: 1.7ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 13.780433333333333 ---------------------------
# 13.780433333333333 ---------------------------
# 13.780433333333333 ---------------------------
# 13.780433333333333 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 machinery, 10.8ms
# Speed: 2.4ms preprocess, 10.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 14.014000000000001 ---------------------------
#
# 0: 384x640 3 trains, 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 14.014000000000001 ---------------------------
# 14.014000000000001 ---------------------------
# 14.014000000000001 ---------------------------
#
# 0: 384x640 2 rails, 9.1ms
# Speed: 1.6ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 14.014000000000001 ---------------------------
# 14.014000000000001 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 Safety Cone, 1 machinery, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 14.247566666666668 ---------------------------
# 14.247566666666668 ---------------------------
#
# 0: 384x640 4 trains, 9.3ms
# Speed: 1.8ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 14.247566666666668 ---------------------------
# 14.247566666666668 ---------------------------
# 14.247566666666668 ---------------------------
# 14.247566666666668 ---------------------------
#
# 0: 384x640 2 rails, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 14.247566666666668 ---------------------------
# 14.247566666666668 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 machinery, 10.4ms
# Speed: 2.5ms preprocess, 10.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 14.481133333333334 ---------------------------
#
# 0: 384x640 4 trains, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 14.481133333333334 ---------------------------
# 14.481133333333334 ---------------------------
# 14.481133333333334 ---------------------------
# 14.481133333333334 ---------------------------
#
# 0: 384x640 3 rails, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 14.481133333333334 ---------------------------
# 14.481133333333334 ---------------------------
# 14.481133333333334 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 Safety Cone, 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 14.7147 ---------------------------
#
# 0: 384x640 3 trains, 9.8ms
# Speed: 2.3ms preprocess, 9.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 14.7147 ---------------------------
# 14.7147 ---------------------------
# 14.7147 ---------------------------
#
# 0: 384x640 3 rails, 9.6ms
# Speed: 2.2ms preprocess, 9.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 14.7147 ---------------------------
# 14.7147 ---------------------------
# 14.7147 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 Safety Cone, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 14.948266666666667 ---------------------------
#
# 0: 384x640 3 trains, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 14.948266666666667 ---------------------------
# 14.948266666666667 ---------------------------
# 14.948266666666667 ---------------------------
#
# 0: 384x640 3 rails, 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 14.948266666666667 ---------------------------
# 14.948266666666667 ---------------------------
# 14.948266666666667 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 Safety Cone, 11.0ms
# Speed: 2.4ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 15.181833333333334 ---------------------------
#
# 0: 384x640 4 trains, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 15.181833333333334 ---------------------------
# 15.181833333333334 ---------------------------
# 15.181833333333334 ---------------------------
# 15.181833333333334 ---------------------------
#
# 0: 384x640 4 rails, 9.9ms
# Speed: 2.0ms preprocess, 9.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 15.181833333333334 ---------------------------
# 15.181833333333334 ---------------------------
# 15.181833333333334 ---------------------------
# 15.181833333333334 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 Safety Cone, 14.4ms
# Speed: 2.4ms preprocess, 14.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# 15.4154 ---------------------------
#
# 0: 384x640 3 trains, 9.1ms
# Speed: 1.8ms preprocess, 9.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 15.4154 ---------------------------
# 15.4154 ---------------------------
# 15.4154 ---------------------------
#
# 0: 384x640 3 rails, 9.0ms
# Speed: 1.7ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 15.4154 ---------------------------
# 15.4154 ---------------------------
# 15.4154 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 Safety Cone, 10.8ms
# Speed: 2.4ms preprocess, 10.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 15.648966666666666 ---------------------------
#
# 0: 384x640 4 trains, 9.0ms
# Speed: 1.9ms preprocess, 9.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 15.648966666666666 ---------------------------
# 15.648966666666666 ---------------------------
# 15.648966666666666 ---------------------------
# 15.648966666666666 ---------------------------
#
# 0: 384x640 3 rails, 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 15.648966666666666 ---------------------------
# 15.648966666666666 ---------------------------
# 15.648966666666666 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 Safety Cone, 12.6ms
# Speed: 2.2ms preprocess, 12.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 15.882533333333333 ---------------------------
#
# 0: 384x640 4 trains, 9.0ms
# Speed: 1.9ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 15.882533333333333 ---------------------------
# 15.882533333333333 ---------------------------
# 15.882533333333333 ---------------------------
# 15.882533333333333 ---------------------------
#
# 0: 384x640 2 rails, 8.8ms
# Speed: 1.7ms preprocess, 8.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 15.882533333333333 ---------------------------
# 15.882533333333333 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 Safety Cone, 12.4ms
# Speed: 2.4ms preprocess, 12.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 16.1161 ---------------------------
#
# 0: 384x640 4 trains, 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 16.1161 ---------------------------
# 16.1161 ---------------------------
# 16.1161 ---------------------------
# 16.1161 ---------------------------
#
# 0: 384x640 3 rails, 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 16.1161 ---------------------------
# 16.1161 ---------------------------
# 16.1161 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 Safety Cone, 12.9ms
# Speed: 2.4ms preprocess, 12.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 16.349666666666668 ---------------------------
#
# 0: 384x640 4 trains, 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 16.349666666666668 ---------------------------
# 16.349666666666668 ---------------------------
# 16.349666666666668 ---------------------------
# 16.349666666666668 ---------------------------
#
# 0: 384x640 2 rails, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 16.349666666666668 ---------------------------
# 16.349666666666668 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 Safety Cone, 11.0ms
# Speed: 2.4ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 16.583233333333332 ---------------------------
#
# 0: 384x640 3 trains, 8.7ms
# Speed: 1.7ms preprocess, 8.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 16.583233333333332 ---------------------------
# 16.583233333333332 ---------------------------
# 16.583233333333332 ---------------------------
#
# 0: 384x640 2 rails, 9.0ms
# Speed: 1.7ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 16.583233333333332 ---------------------------
# 16.583233333333332 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 1 Safety Cone, 9.8ms
# Speed: 2.3ms preprocess, 9.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 16.8168 ---------------------------
#
# 0: 384x640 3 trains, 9.0ms
# Speed: 1.9ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 16.8168 ---------------------------
# 16.8168 ---------------------------
# 16.8168 ---------------------------
#
# 0: 384x640 2 rails, 8.7ms
# Speed: 1.8ms preprocess, 8.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 16.8168 ---------------------------
# 16.8168 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 (no detections), 9.9ms
# Speed: 2.5ms preprocess, 9.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 9.1ms
# Speed: 2.2ms preprocess, 9.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 17.050366666666665 ---------------------------
# 17.050366666666665 ---------------------------
#
# 0: 384x640 2 rails, 9.0ms
# Speed: 2.1ms preprocess, 9.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 17.050366666666665 ---------------------------
# 17.050366666666665 ---------------------------
# Predicted label: blizko1
#
# 0: 384x640 2 machinerys, 9.0ms
# Speed: 2.3ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 17.283933333333334 ---------------------------
# 17.283933333333334 ---------------------------
#
# 0: 384x640 1 train, 9.3ms
# Speed: 2.1ms preprocess, 9.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 17.283933333333334 ---------------------------
#
# 0: 384x640 2 rails, 9.4ms
# Speed: 2.2ms preprocess, 9.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 17.283933333333334 ---------------------------
# 17.283933333333334 ---------------------------
# Predicted label: blizko1
